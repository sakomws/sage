# %%
import jax.numpy as jnp
import jax
import jax.random as jr
import numpy as np

# %%
rng = jr.key(0)
jr.randint(rng, (100_000,), 0, 256)[:1000]
# Out:
# Array([207, 142, 111, 116,  24,  39,  36,  25, 199, 235,  18, 194, 137,
#         89, 113, 100,  21, 215,  94, 190, 253,  56,  98,  16,  68,  98,
#         21,  21, 169, 121,  94, 247, 150,   6, 202,  20, 221, 198,  79,
#        147, 255, 217, 166,  64,  91, 202,  66, 212, 133,  89,  10,  34,
#         59, 170, 124, 134,  16,  84,   6, 145, 116, 131, 235,  54, 186,
#         38, 129,  87, 148, 152, 107,  56, 196,  58, 151,  25,   7, 173,
#          9,  20, 237, 141,   5,   4,  52, 113, 168,  13,  46, 149,  83,
#        181,  86, 174,  73, 165,  79,  59,   4,  88,  26, 124,  63, 115,
#        149,   5, 255, 226, 114, 233, 147, 135,  52,  17, 173,  30, 136,
#         61, 252, 104, 183, 197,  87,  18,  86, 147, 237, 146, 135,  22,
#        241,   7,  56, 112,  46,  87, 139, 238, 212, 161,  48,  30,  83,
#        241,  11,  35,  43, 216,  28, 146, 171,  49, 234, 133, 140, 191,
#        172, 216, 239, 231,  41, 157, 121, 191,  99,  91,  93,  16,  91,
# ...
